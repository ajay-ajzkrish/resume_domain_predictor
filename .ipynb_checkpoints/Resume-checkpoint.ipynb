# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading Data

# %%
df = pd.read_csv('UpdatedResumeDataSet.csv')
df.head()
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %%
df.shape
# Out:
# (962, 2)

# %% [markdown]
# ## Categories

# %%
plt.figure(figsize = (15,5))
df['Category'].value_counts(normalize = True).plot(kind = 'bar')
plt.show()

# %% [markdown]
# ## Exploration

# %%
df['Resume'][0]
# Out:
# 'Skills * Programming Languages: Python (pandas, numpy, scipy, scikit-learn, matplotlib), Sql, Java, JavaScript/JQuery. * Machine learning: Regression, SVM, NaÃ¯ve Bayes, KNN, Random Forest, Decision Trees, Boosting techniques, Cluster Analysis, Word Embedding, Sentiment Analysis, Natural Language processing, Dimensionality reduction, Topic Modelling (LDA, NMF), PCA & Neural Nets. * Database Visualizations: Mysql, SqlServer, Cassandra, Hbase, ElasticSearch D3.js, DC.js, Plotly, kibana, matplotlib, ggplot, Tableau. * Others: Regular Expression, HTML, CSS, Angular 6, Logstash, Kafka, Python Flask, Git, Docker, computer vision - Open CV and understanding of Deep learning.Education Details \r\n\r\nData Science Assurance Associate \r\n\r\nData Science Assurance Associate - Ernst & Young LLP\r\nSkill Details \r\nJAVASCRIPT- Exprience - 24 months\r\njQuery- Exprience - 24 months\r\nPython- Exprience - 24 monthsCompany Details \r\ncompany - Ernst & Young LLP\r\ndescription - Fraud Investigat
# ...

# %% [markdown]
# ## Cleaning

# %%
import re
def cleanResume(txt):
    cleanText = re.sub('http\S+\s', ' ', txt)
    cleanText = re.sub('RT|cc', ' ', cleanText)
    cleanText = re.sub('#\S+\s', ' ', cleanText)
    cleanText = re.sub('@\S+', '  ', cleanText)  
    cleanText = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', cleanText)
    cleanText = re.sub(r'[^\x00-\x7f]', ' ', cleanText) 
    cleanText = re.sub('\s+', ' ', cleanText)
    return cleanText

# %%
# k = cleanresume("dlfjl   http://sdflkjs.com and ### #ljsdjl gmril is akasdkj@aldk.com")
# print(k)

# %%
df['Resume'].apply(lambda x : cleanResume(x))
# Out:
# 0      Skills Programming Languages Python pandas num...
# 1      Education Details May 2013 to May 2017 B E UIT...
# 2      Areas of Interest Deep Learning Control System...
# 3      Skills R Python SAP HANA Tableau SAP HANA SQL ...
# 4      Education Details MCA YMCAUST Faridabad Haryan...
#                              ...
# 957    Computer Skills Proficient in MS office Word B...
# 958     Willingness to a ept the challenges Positive ...
# 959    PERSONAL SKILLS Quick learner Eagerness to lea...
# 960    COMPUTER SKILLS SOFTWARE KNOWLEDGE MS Power Po...
# 961    Skill Set OS Windows XP 7 8 8 1 10 Database MY...
# Name: Resume, Length: 962, dtype: object

# %%
df['Resume'][0]
# Out:
# 'Skills * Programming Languages: Python (pandas, numpy, scipy, scikit-learn, matplotlib), Sql, Java, JavaScript/JQuery. * Machine learning: Regression, SVM, NaÃ¯ve Bayes, KNN, Random Forest, Decision Trees, Boosting techniques, Cluster Analysis, Word Embedding, Sentiment Analysis, Natural Language processing, Dimensionality reduction, Topic Modelling (LDA, NMF), PCA & Neural Nets. * Database Visualizations: Mysql, SqlServer, Cassandra, Hbase, ElasticSearch D3.js, DC.js, Plotly, kibana, matplotlib, ggplot, Tableau. * Others: Regular Expression, HTML, CSS, Angular 6, Logstash, Kafka, Python Flask, Git, Docker, computer vision - Open CV and understanding of Deep learning.Education Details \r\n\r\nData Science Assurance Associate \r\n\r\nData Science Assurance Associate - Ernst & Young LLP\r\nSkill Details \r\nJAVASCRIPT- Exprience - 24 months\r\njQuery- Exprience - 24 months\r\nPython- Exprience - 24 monthsCompany Details \r\ncompany - Ernst & Young LLP\r\ndescription - Fraud Investigat
# ...

# %% [markdown]
# ## words to cat

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le.fit(df['Category'])
df['Category_Encoded'] = le.transform(df['Category'])
df.head(3)
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
#
#    Category_Encoded
# 0                 6
# 1                 6
# 2                 6

# %% [markdown]
# ## Vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf.fit(df['Resume'])
resume_vector = tfidf.transform(df['Resume'])
df.head(2)
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
#
#    Category_Encoded
# 0                 6
# 1                 6

# %%
resume_vector
# Out:
# <962x7384 sparse matrix of type '<class 'numpy.float64'>'
# 	with 164274 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(resume_vector, df['Category_Encoded'], test_size=0.2, random_state=42)

# %% [markdown]
# ## Training

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
clf = KNeighborsClassifier()
clf.fit(X_train, y_train)

ypred = clf.predict(X_test)
accuracy_score(y_test,ypred)
# Out:
# 0.9844559585492227

# %%
# from sklearn.multiclass import OneVsOneClassifier
# from sklearn.tree import DecisionTreeClassifier

# %%
# dt = DecisionTreeClassifier()
# clf = OneVsOneClassifier(estimator=dt)
# clf.fit(X_train, y_train)

# ypred = clf.predict(X_test)
# accuracy_score(y_test,ypred)

# %%
import pickle

pickle.dump(tfidf,open('tfidf.pkl', 'wb'))
pickle.dump(clf, open('clf.pkl','wb'))

# %%
#Creating a dictionary for category and encoded category

encoded = df['Category_Encoded'].unique()
cat = df['Category'].unique()

# %%
category_mapper = {}
for i in range(len(encoded)):
    category_mapper[encoded[i]] = cat[i]

# %%
category_mapper
# Out:
# {6: 'Data Science',
#  12: 'HR',
#  0: 'Advocate',
#  1: 'Arts',
#  24: 'Web Designing',
#  16: 'Mechanical Engineer',
#  22: 'Sales',
#  14: 'Health and fitness',
#  5: 'Civil Engineer',
#  15: 'Java Developer',
#  4: 'Business Analyst',
#  21: 'SAP Developer',
#  2: 'Automation Testing',
#  11: 'Electrical Engineering',
#  18: 'Operations Manager',
#  20: 'Python Developer',
#  8: 'DevOps Engineer',
#  17: 'Network Security Engineer',
#  19: 'PMO',
#  7: 'Database',
#  13: 'Hadoop',
#  10: 'ETL Developer',
#  9: 'DotNet Developer',
#  3: 'Blockchain',
#  23: 'Testing'}

# %% [markdown]
# # My actual Resume text

# %%
my_resume_text = """AJAY KRISHNAN
Email: akrishnan.work@gmail.com | Location: Chennai |LinkedIn| GitHub | Website
OBJECTIVE
Data Science postgraduate with a Bachelor's in Computer Science. 1.5 years of corporate experience, dedicated to 
contributing knowledge and skills in a professional work-driven environment for personal growth and organizational success.
WORK EXPERIENCE
Jr. SAP ABAP Consultant
Cognizant, Chennai, Tamil Nadu
Feb 2022 - May 2023
- Managed and resolved tickets and routine tasks efficiently.
- Prepared daily and weekly reports.
- Scheduled meetings as needed to facilitate project coordination.
- Conducted knowledge transfer for new team members.
Web Development Intern
Big Binary, Kochi, Kerala
August 2021 (5 months)
- Assisted in the team with HTML, CSS, and React.
PROJECTS
1. Credit Card Fraud Detection using Supervised Learning Classification -Classification (link)
 - Developed a machine learning model to classify transactions as fraudulent or legitimate.
 - Utilized supervised learning techniques on a labelled dataset.
2. Students Performance in Exams - Regression(link)
 - Analysed the influence of various factors like parental background and test preparation on students' academic 
performance.
 - Predicted students' exam scores.
3. HR Analytics Dashboard – Power BI (link)
 - Created an HR analytics dashboard using Power BI to visualize and analyse human resources data for informed decisionmaking.
EDUCATION
PG Programme (Data Science)
Great Lakes, Chennai
2021-2023
Bachelor of Technology (CSE)
Rajagiri School of Engineering and Technology
2017-2021
EXPERTISE
Programming Languages: Python for Data Science, SQL, R (Basics), NumPy, HTML, CSS
Tools/Libraries: Power BI, MS Office, Matplotlib, NLP, TensorFlow, GCP, Excel, Git
Databases: MySQL, PostgreSQL
Soft Skills: Effective Time Management, Ability to Multitask, Adaptability, Team Player, Effective communication skills.
Languages: English, Malayalam, Tamil, Hindi"""

# %%
import pickle

#loading classifier (trained)

clf = pickle.load(open('clf.pkl','rb'))
tfidf = pickle.load(open('tfidf.pkl','rb'))

#Cleaning the resume
my_resume_text_cleaned = cleanResume(my_resume_text)


#transformation
ip_features = tfidf.transform([my_resume_text_cleaned])
 

#predicitons

prediction = clf.predict(ip_features)[0]   #only one element, hence taking 1st value from returned array

# %%
prediction
# Out:
# 6

# %%
category_predicted = category_mapper.get(prediction, 'Unknown')
category_predicted
# Out:
# 'Data Science'

# %%
# YUP, i am an aspiring data scientist!!
